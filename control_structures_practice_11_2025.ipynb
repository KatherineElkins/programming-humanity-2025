# %% [markdown]
# <a href="https://colab.research.google.com/github/KatherineElkins/programming-humanity-2025/blob/main/control_structures_practice_11_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Written by K. Elkins 11/11/2025
# Practice upon completion of Datacamp Intermediate Python Loops (Chapter 4)

# %% [markdown]
# ## 🔁 Part 1: FOR LOOPS
#
# For loops let you repeat code a specific number of times or iterate through a collection.
#
# **Syntax:**
# ```python
# for variable in sequence:
#     # code to repeat
# ```
#
# Let's see an example, then you'll try some exercises!

# %%
# Example: Print numbers 1-5
print("Example - Counting:")
for i in range(1, 6):
    print(f"Count: {i}")

# %% [markdown]
# ### ✏️ Exercise 1: Print your name 3 times
# Use a for loop to print your name 3 times.

# %%
# Exercise 1: Use a for loop to print your name 3 times
# Write your code here:

# %% [markdown]
# ### ✏️ Exercise 2: Print squares
# Use a for loop to print the squares of numbers 1-10.
#
# **Hint:** Use `range(1, 11)` and remember that `x**2` means "x squared"

# %%
# Exercise 2: Use a for loop to print the squares of numbers 1-10
# Write your code here:

# %% [markdown]
# ### ✏️ Exercise 3: Loop through a list
# Loop through this list and print each item with its index.
#
# **Hint:** Use `enumerate()` or keep track of an index variable

# %%
# Exercise 3: Loop through this list and print each item with its index
fruits = ["apple", "banana", "cherry", "date"]
# Write your code here:

# %% [markdown]
# ---
# ## 🔄 Part 2: WHILE LOOPS
#
# While loops repeat code as long as a condition is true. Be careful - if the condition never becomes false, you'll have an infinite loop!
#
# **Syntax:**
# ```python
# while condition:
#     # code to repeat
#     # don't forget to update the condition!
# ```

# %%
# Example: Countdown
print("Example - Countdown:")
count = 5
while count > 0:
    print(count)
    count -= 1
print("Blast off!")

# %% [markdown]
# ### ✏️ Exercise 4: Doubling numbers
# Create a while loop that doubles a number starting from 1. Stop when the number exceeds 100.
#
# **Hint:** Start with `number = 1`, then use `number = number * 2` or `number *= 2`

# %%
# Exercise 4: Create a while loop that doubles a number starting from 1
# Stop when the number exceeds 100
# Write your code here:
number = 1
while number <= 100:
  print(number)
  number = number *2
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64

# %% [markdown]
# ### ✏️ Exercise 5: Counting down
# Use a while loop to count down from 10 to 1, then print "Done!"
#
# **Hint:** Remember to decrease your counter variable each time through the loop

# %%
# Exercise 5: Use a while loop to count down from 10 to 1
# Write your code here:

# %% [markdown]
# ## 🤔 Part 3: IF/ELIF/ELSE
#
# Conditional statements let your code make decisions based on conditions.
#
# **Syntax:**
# ```python
# if condition:
#     # runs if condition is true
# elif another_condition:
#     # runs if first condition is false but this one is true
# else:
#     # runs if all conditions are false
# ```

# %%
# Example: Grade checker
print("Example - Grade checker:")
score = 85
if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
else:
    print("Grade: F")

# %% [markdown]
# ### ✏️ Exercise 6: Temperature checker
# Write a temperature checker:
# - If temp > 80: print "Hot"
# - If temp between 60-80: print "Nice"
# - If temp below 60: print "Cold"

# %%
# Exercise 6: Write a temperature checker
temperature = 72
# Write your code here:

# %% [markdown]
# ### ✏️ Exercise 7: Positive, negative, or zero?
# Check if a number is positive, negative, or zero and print the result.
#
# Try changing the value of `number` to test different cases!

# %%
# Exercise 7: Check if a number is positive, negative, or zero
number = -5
# Write your code here:

# %% [markdown]
# ## 🌟 Part 4: CHALLENGE - COMBINING STRUCTURES
#
# Now let's combine everything you've learned! These challenges use loops AND conditionals together.

# %% [markdown]
# ### 🎯 Challenge 1: FizzBuzz
# This is a classic programming challenge!
#
# Loop through numbers 1-30:
# - If divisible by 3: print "Fizz"
# - If divisible by 5: print "Buzz"
# - If divisible by BOTH 3 and 5: print "FizzBuzz"
# - Otherwise: print the number
#
# **Hint:** Use the modulo operator `%` to check divisibility. Example: `15 % 3 == 0` is True

# %%
# Challenge 1: FizzBuzz
# Write your code here:

# %% [markdown]
# ### 🎯 Challenge 2: Guessing game simulation
# Create a guessing game simulation:
# - Use a while loop with a secret number
# - Use if/elif/else to give "too high" or "too low" hints
# - We'll simulate guesses with a list instead of real user input
#
# **Hint:** Use a counter to track which guess you're on, and stop when you find the right number or run out of guesses

# %%
# Challenge 2: Create a guessing game simulation
secret_number = 42
guesses = [30, 50, 40, 43, 42]  # Simulated guesses
# Write your code here:

# %% [markdown]
# ## 🎉 Great work!
#
# You've practiced:
# - ✅ For loops
# - ✅ While loops
# - ✅ If/elif/else statements
# - ✅ Combining them together
#
# **Next steps:** Try creating your own exercises or modify these to do something different!
